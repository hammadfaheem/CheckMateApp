# %%
import PyPDF2

def read_pdf_pages(file_path):
        reader = PyPDF2.PdfReader(file_path)
        return reader.pages
        # num_pages = len(reader.pages)
        # content = ""
        # for page_num in range(num_pages):
        #     page = reader.pages[page_num]
        #     text = page.extract_text()
        #     text = text.replace("\n", " ")
        #     text = "\n".join(["Question" + paragraph for paragraph in text.split("Question")])
        #     content += text
        # return content

# %%
pages = read_pdf_pages("/home/hammad/Project/assignment_chack/EB21102029_Hammad_Faheem.pdf")

# %%
pages[0].extract_text().strip().replace("\n", " ")
# Out:
# 'Networking Basics Assignment Instructions: Answer the following questions to the best of your ability. Leave space for detailed responses where necessary. Question 1: What is a computer network, and why is it important in today’s digital world? Answer: A computer network is just like some wires and stuff. It’s important because... I guess we use it for, like, Netflix? Question 2: Describe the differences between a Local Area Network (LAN) and a Wide Area Network (WAN). Provide examples of where each might be used. Answer: LAN and WAN are just different. I don’t really know the difference. I think a LAN is in my room, and WAN is maybe, like, outside? Question 3: What is the role of a router in a network? How does it differ from a switch? Answer: The router is the thing with the antennas. The switch... I think it’s a button on the router? I don’t know.'

# %%
! pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3958 sha256=4bea8e1606ffcbf2bab4a42cd942f7072b36d1053b86f8566c10a1bc5b242955
#   Stored in directory: /home/hammad/.cache/pip/wheels/0f/0e/7a/3094a4ceefe657bff7e12dd9592a9d5b6487ef4338ace0afa6
# Successfully built docx2txt
# ...

# %%
import docx2txt

text = docx2txt.process("path/to/your/file.docx")
print(text)

# %%
import docx

# %%
from docx import Document

# Open the docx file
doc = Document("/home/hammad/Project/assignment_chack/CheckMate FYP.docx")

# Read and print all paragraphs
for para in doc.paragraphs:
    print(para.text)
# Out:
# CheckMate
# Say No to Manual Grading!
#
#
#
# SUPERVISORS
# Dr Shaista Raees & Dr Sadiq Ali Khan
#
#
#
#
#
# SUBMITTED BY
#
#
# HAMMAD FAHEEM                                           EB21102029
#
# HASSAN QAMAR                                               EB21102037
#
# MUHAMMAD UMER SALEEM                        EB20102098
#
#
#
#
#
#
# DEPARTMENT OF COMPUTER SCIENCE
# UNIVERSITY OF KARACHI
#
#
# CheckMate
# Say No to Manual Grading!
# 18.02.2025
#
#
# Session: BSCS 2021 - 2025  (Evening)
#
#
# Submitted By:
#
#
# HAMMAD FAHEEM                                           EB21102029
#
# HASSAN QAMAR                                               EB21102037
#
# MUHAMMAD UMER SALEEM                        EB20102098
#
#
#
#
#
#
#
# Table Of Content
#
#
#
#
#
# ABSTRACT
# SUMMARY
# ...
